# %% [markdown]
# -------------------------------------------------------------------------------------------------
#
# ### Preprocessing Video
#
# Working on streamlining the preprocessing. Will attempt to pull frame 100 from the entire dataset. Plan is to use cv2 to grab the frame and save the frame to a list. Then use facenet to detect face and crop on face. And then save to disk.
#
# <img style="float: center;" src="deepfake.jpg">
#
# -------------------------------------------------------------------------------------------------

# %%
# !pip3 install torch --user
# Out:
# Collecting torch
#   Downloading https://files.pythonhosted.org/packages/1a/3b/fa92ece1e58a6a48ec598bab327f39d69808133e5b2fb33002ca754e381e/torch-1.4.0-cp37-cp37m-manylinux1_x86_64.whl (753.4MB)
#     58% |██████████████████▋             | 437.0MB 94.1MB/s eta 0:00:044
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#     67% |█████████████████████▋          | 509.6MB 97.0MB/s eta 0:00:03
#     68% |█████████████████████▉          | 514.4MB 94.9MB/s eta 0:00:03
#     68% |██████████████████████          | 519.2MB 92.6MB/s eta 0:00:03
#     69% |██████████████████████▎         | 524.1MB 88.2MB/s eta 0:00:03
#     70% |██████████████████████▌         | 528.9MB 91.1MB/s eta 0:00:03
#     70% |██████████████████████▋         | 533.6MB 96.4MB/s eta 0:00:03
#     71% |██████████████████████▉         | 538.5MB 94.1MB/s eta 0:00:03
#     72% |███████████████████████         | 543.3MB 95.8MB/s eta 0:00:03
#     72% |███████████████████████▎        | 548.0MB 95.8MB/s eta 0:00:03
#     73% |███████████████████████▌        | 552.8MB 96.8MB/s eta 0:00:03
#     74% |███████████████████████▊        | 557.6MB 97.4MB/s eta 0:00:03
#     74% |███████████████████████▉        | 562.4MB 99.4MB/s eta 0:00:02
#     75% |████████████████████████        | 567.2MB 99.7MB/s eta 0:00:02
#     75% |████████████████████████▎       | 571.9MB 89.1MB/s eta 0:00:03
#     76% |████████████████████████▌       | 576.8MB 99.1MB/s eta 0:00:02
#     77% |████████████████████████▊       | 581.6MB 90.1MB/s eta 0:00:02
#     77% |█████████████████████████       | 586.4MB 93.1MB/s eta 0:00:02
#     78% |█████████████████████████       | 591.2MB 94.9MB/s eta 0:00:02
#     79% |█████████████████████████▎      | 596.0MB 99.6MB/s eta 0:00:02
#     79% |█████████████████████████▌      | 600.9MB 100.0MB/s eta 0:00:02
#     80% |█████████████████████████▊      | 605.7MB 91.6MB/s eta 0:00:02
#     81% |██████████████████████████      | 610.5MB 95.5MB/s eta 0:00:02
#     81% |██████████████████████████▏     | 615.4MB 95.0MB/s eta 0:00:02
#     82% |██████████████████████████▍     | 620.2MB 98.4MB/s eta 0:00:02
#     82% |██████████████████████████▌     | 625.0MB 89.4MB/s eta 0:00:02
#     83% |██████████████████████████▊     | 629.9MB 88.6MB/s eta 0:00:02
#     84% |███████████████████████████     | 634.7MB 99.8MB/s eta 0:00:02
#     84% |███████████████████████████▏    | 639.5MB 96.8MB/s eta 0:00:02
#     85% |███████████████████████████▍    | 644.3MB 99.1MB/s eta 0:00:02
#     86% |███████████████████████████▋    | 649.1MB 93.1MB/s eta 0:00:02
#     86% |███████████████████████████▊    | 654.0MB 84.8MB/s eta 0:00:02
#     87% |████████████████████████████    | 658.8MB 88.4MB/s eta 0:00:02
#     88% |████████████████████████████▏   | 663.6MB 102.3MB/s eta 0:00:01
#     88% |████████████████████████████▍   | 668.4MB 92.2MB/s eta 0:00:01
#     89% |████████████████████████████▋   | 673.2MB 90.4MB/s eta 0:00:01
#     90% |████████████████████████████▉   | 678.1MB 98.9MB/s eta 0:00:01
#     90% |█████████████████████████████   | 682.8MB 93.6MB/s eta 0:00:01
#     91% |█████████████████████████████▏  | 687.6MB 100.4MB/s eta 0:00:01
#     91% |█████████████████████████████▍  | 692.1MB 91.4MB/s eta 0:00:01
#     92% |█████████████████████████████▋  | 696.9MB 106.0MB/s eta 0:00:01
#     93% |█████████████████████████████▉  | 701.7MB 98.1MB/s eta 0:00:01
#     93% |██████████████████████████████  | 706.5MB 97.9MB/s eta 0:00:01
#     94% |██████████████████████████████▏ | 711.3MB 92.5MB/s eta 0:00:01
#     95% |██████████████████████████████▍ | 716.2MB 91.6MB/s eta 0:00:01
#     95% |██████████████████████████████▋ | 721.0MB 91.4MB/s eta 0:00:01
#     96% |██████████████████████████████▉ | 725.8MB 95.3MB/s eta 0:00:01
#     96% |███████████████████████████████ | 730.7MB 98.8MB/s eta 0:00:01
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#     100% |████████████████████████████████| 753.4MB 2.1kB/s
# Installing collected packages: torch
# Successfully installed torch-1.4.0

# %%
# !pip3 install pandas --user
# Out:
# Collecting pandas
#   Downloading https://files.pythonhosted.org/packages/16/cf/5d4614610a6be006ea5715f76e261cb8bc0031a97e43f9915bddb404a3f5/pandas-1.0.0-cp37-cp37m-manylinux1_x86_64.whl (10.0MB)
#     100% |████████████████████████████████| 10.1MB 159kB/s  eta 0:00:01
# Requirement already satisfied: numpy>=1.13.3 in /home/ec2-user/.local/lib/python3.7/site-packages (from pandas)
# Requirement already satisfied: python-dateutil>=2.6.1 in /home/ec2-user/.local/lib/python3.7/site-packages (from pandas)
# Collecting pytz>=2017.2 (from pandas)
#   Downloading https://files.pythonhosted.org/packages/e7/f9/f0b53f88060247251bf481fa6ea62cd0d25bf1b11a87888e53ce5b7c8ad2/pytz-2019.3-py2.py3-none-any.whl (509kB)
#     100% |████████████████████████████████| 512kB 3.5MB/s  eta 0:00:01
# Requirement already satisfied: six>=1.5 in /home/ec2-user/.local/lib/python3.7/site-packages (from python-dateutil>=2.6.1->pandas)
# Installing collected packages: pytz, pandas
# Successfully installed pandas-1.0.0 pytz-2019.3

# %%
# from pypi https://pypi.org/project/facenet-pytorch/
# !pip3 install facenet-pytorch --user
#
# install facenet-pytorch on kaggle without internet
# !pip install ../facenet-pytorch/facenet_pytorch-2.0.0-py3-none-any.whl --user
# Out:
# Collecting facenet-pytorch
#   Using cached https://files.pythonhosted.org/packages/ce/60/5192979f70b14681c698f61aace14e906bc92abc0790b0002ebd017dd3d3/facenet_pytorch-2.0.1-py3-none-any.whl
# Requirement already satisfied: numpy in /home/ec2-user/.local/lib/python3.7/site-packages (from facenet-pytorch)
# Collecting requests (from facenet-pytorch)
#   Using cached https://files.pythonhosted.org/packages/51/bd/23c926cd341ea6b7dd0b2a00aba99ae0f828be89d72b2190f27c11d4b7fb/requests-2.22.0-py2.py3-none-any.whl
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/ec2-user/.local/lib/python3.7/site-packages (from requests->facenet-pytorch)
# Collecting certifi>=2017.4.17 (from requests->facenet-pytorch)
#   Using cached https://files.pythonhosted.org/packages/b9/63/df50cac98ea0d5b006c55a399c3bf1db9da7b5a24de7890bc9cfd5dd9e99/certifi-2019.11.28-py2.py3-none-any.whl
# Collecting chardet<3.1.0,>=3.0.2 (from requests->facenet-pytorch)
#   Using cached https://files.pythonhosted.org/packages/bc/a9/01ffebfb562e4274b6487b4bb1ddec7ca55ec7510b22e4c51f14098443b8/chardet-3.0.4-py2.py3-none-any.whl
# Collecting idna<2.9,>=2.5 (from requests->facenet-pytorch)
#   Using cached https://files.pythonhosted.org/packages/14/2c/cd551d81dbe15200be1cf41cd03869a46fe7226e7450af7a6545bfc474c9/idna-2.8-py2.py3-none-any.whl
# Installing collected packages: certifi, chardet, idna, requests, facenet-pytorch
# Successfully installed certifi-2019.11.28 chardet-3.0.4 facenet-pytorch-2.0.1 idna-2.8 requests-2.22.0

# %%
import os
import json
import pandas as pd
import cv2
import numpy as np
from matplotlib import pyplot as plt
from PIL import Image
import torch
from tqdm import tqdm
import time
from joblib import Parallel, delayed
from facenet_pytorch import MTCNN

device = 'cuda:0' if torch.cuda.is_available() else 'cpu'

# %%
# set deepfake directory chunk
chunk = 0
# frame number to grab from videos
frame_num = 99

# %%
video_dir = f'/data/deepfake/dfdc_train_part_{chunk}'
frame_dir = f'/data/frames/f{frame_num}'
meta_file = os.path.join(video_dir, 'metadata.json')

os.makedirs(frame_dir, exist_ok=True)

with open(meta_file) as f:
    metadata = pd.read_json(f).T

# %%
def grab_frames(sample, frame_num):
    video = os.path.join(video_dir, sample)
    filename = sample[:-3]+'jpg'
    reader = cv2.VideoCapture(video)
    reader.set(1, frame_num)
    _, image = reader.read()
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    images_dict = {}
    images_dict[filename] = image
    reader.release()
    return image, images_dict
# Out:
# "\nimages_dict = {}\nimages = []\nfor sample in tqdm(metadata.index):\n    filename = sample[:-3]+'jpg'\n    frame = grab_frames(sample, frame_num)\n    images_dict[filename] = frame\n    images.append(frame)\n    \nprint(f'Grabbing frames from deepfake video directory #{chunk}')\n"

# %%
results = Parallel(n_jobs=20)(delayed(
                   grab_frames)(sample, frame_num)
                       for sample in metadata.index)

# unpack reults
images, results_dict = zip(*results)
images = list(images)
images_dict = {}
for i in results_dict:
    images_dict.update(i)

# %%
def timer(detector, detect_fn, images, *args):
    start = time.time()
    faces, faces_dict = detect_fn(detector, images, *args)
    elapsed = time.time() - start
    print(f', {elapsed:.3f} seconds')
    return faces, elapsed, faces_dict

# %%
# my attempt at adding a dictionary to the for loop to keep track of filenames

detector = MTCNN(image_size=224, device=device, post_process=False)


def detect_facenet_pytorch(detector, images, batch_size):
    faces = []
    faces_dict = {}
    n = 0
    for key in images_dict.keys():
    #for lb in np.arange(0, len(images), batch_size):
        imgs_pil = [Image.fromarray(images_dict[key])]
        #print(type(imgs_pil[0]))
        try:
            faces.extend(detector(imgs_pil))
            #print(len(faces))
            faces_dict[key] = faces[n]
            n += 1
        except:
            pass
    return faces, faces_dict

times_facenet_pytorch_nb = [] # non-batched

# %%
# dtect faces from images
print('Detecting faces in frames', end='')
faces, elapsed, faces_dict = timer(detector, detect_facenet_pytorch, images, 1)
times_facenet_pytorch_nb.append(elapsed)
# Out:
# Detecting faces in frames, 440.037 seconds

# %%
for face in faces_dict.keys():
    try:
        image = faces_dict[face].permute(1, 2, 0).int().numpy()
        filename = os.path.join(frame_dir, face)
        cv2.imwrite(filename, image)
    except:
        faces_dict[face] = 'no face detected'
        pass

# %%
no_faces_detected = 0
for face in faces_dict.keys():
    if isinstance(faces_dict[face], str):
        no_faces_detected += 1
        
print(f'{no_faces_detected} frames without faces detected')
# Out:
# 0 frames without faces detected

# %%
len(os.listdir(frame_dir))
# Out:
# 1334

# %%
len(os.listdir(video_dir))
# Out:
# 1339

# %%
chunk = 1
frame_num = 250

def main(chunk, frame_num):
    video_dir = f'/data/deepfake/dfdc_train_part_{chunk}'
    frame_dir = f'/data/frames/f{frame_num}'
    meta_file = os.path.join(video_dir, 'metadata.json')
    os.makedirs(frame_dir, exist_ok=True)
    with open(meta_file) as f:
        metadata = pd.read_json(f).T
        
    # parallel process cv2
    print('Parallel processing cv2')
    results = Parallel(n_jobs=20)(delayed(
                   grab_frames)(sample, frame_num)
                       for sample in metadata.index)

    # unpack reults
    images, results_dict = zip(*results)
    images = list(images)
    images_dict = {}
    for i in results_dict:
        images_dict.update(i)
        
    # dtect faces from images
    print('Detecting faces in frames', end='')
    faces, elapsed, faces_dict = timer(detector, detect_facenet_pytorch, images, 1)
    times_facenet_pytorch_nb.append(elapsed)
    
    # write images to disk
    for face in faces_dict.keys():
    try:
        image = faces_dict[face].permute(1, 2, 0).int().numpy()
        filename = os.path.join(frame_dir, face)
        cv2.imwrite(filename, image)
    except:
        faces_dict[face] = 'no face detected'
        pass
    
    # finishing up
    no_faces_detected = 0
    for face in faces_dict.keys():
        if isinstance(faces_dict[face], str):
            no_faces_detected += 1
        
    print(f'{no_faces_detected} frames without faces detected')
