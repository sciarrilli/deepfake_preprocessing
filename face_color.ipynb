# %%
import json
import cv2
import os
import shutil
import numpy as np
from tqdm import tqdm
from dlib import get_frontal_face_detector
from matplotlib import pyplot as plt
import multiprocessing as mp
from joblib import Parallel, delayed
import boto3

# %%
# change the chunk # and run thru the entire script

chunk = 49

# %%
color_dir = f'/data/deepfake/dfdc_train_part_{chunk}/color'

fake_dir = f'/data/deepfake/dfdc_train_part_{chunk}/faces/fake'

# %%
# make  directory


os.makedirs(color_dir, exist_ok=True)

# %%
fake_image_list = os.listdir(fake_dir)

# %%
fake_image_list[0].split('/')[-1]
# Out:
# 'advhlnfwag_150.jpg'

# %%
fake_image_list = [os.path.join(fake_dir, image) for image in fake_image_list]

# %%
fake_image_list[0]
# Out:
# '/data/deepfake/dfdc_train_part_49/faces/fake/advhlnfwag_150.jpg'

# %%
detector = get_frontal_face_detector()


def detectFaces(imageFile, output):
    faces = []
    filename = imageFile.split('/')[-1]
    out_path = os.path.join(output, filename)

    image = cv2.imread(imageFile, 1)
    #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    #gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    faces = detector(image, 2)

    if len(faces) > 0:
        face = faces[0]
    else:
        face = faces
    
    try:
        face_image = image[face.top():face.bottom(), face.left():face.right()]
        face_image = cv2.resize(face_image, (224, 224))

        cv2.imwrite(out_path, face_image)
        
    except:
        pass

# %%
mp.cpu_count()
# Out:
# 72

# %%
detectFaces(fake_image_list[200], color_dir)

# %%
mp.cpu_count()
# parallel process real images
Parallel(n_jobs=55)(delayed(detectFaces)(image, faces_real_dir) for image in real_image_list)
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
# parallel process fake images
Parallel(n_jobs=55)(delayed(detectFaces)(image, faces_fake_dir) for image in fake_image_list)
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ...]

# %%
sns = boto3.client('sns')
response = sns.publish(
    TopicArn='arn:aws:sns:us-east-1:364430515305:deepfake',
    Message=f' detectFaces chunk #{chunk} finished processing'
)
